# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import folium
from sklearn.preprocessing import LabelEncoder
from geopy.geocoders import Yandex
from geopy.distance import vincenty
from time import time
from tqdm import tqdm

# %%
train = pd.read_csv('data/train_set.csv')
test = pd.read_csv('data/test_set.csv')

train.rename(columns={ 'pos_adress_lat' : 'pos_address_lat', 
                       'pos_adress_lon' : 'pos_address_lon'}, inplace=True)
# Out:
# D:\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (1,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# D:\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (1,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Удалить транзакции, где нет адреса координат atm, pos и terminal_id (в трейне это все строчки, где нет terminal_id)
train.drop(train[train['terminal_id'].isnull() == True].index, axis=0, inplace=True)

# %%
# Подсчет частот адресов
atm_address_count = train['atm_address'].value_counts()

# Удаление транзакций с atm_address = "RADNAYA\             RUS,445" (по нему координат нет)
# train.drop(train[train['atm_address'] == atm_address_count.index[45]].index, axis=0, inplace=True)

# Замена 'Подольск, ул. Полевановская, д. 9, (Заезд с ул. Орджоникидзе д. 25)' на 'Подольск, ул. Полевановская, д. 9'
train['atm_address'].replace(to_replace=atm_address_count.index[46], value='Подольск, ул. Полевановская, д. 9', inplace=True)

# %%
# Адреса с '\' в названии (частоты)
backslash_atm_address_count = train['atm_address'][train['atm_address'].str.contains("\\\\") == True].value_counts()

# Замены до частоты 100 более-менее читаемых адресов
train['atm_address'].replace(to_replace=backslash_atm_address_count.index[1], value='улица Маросейка, 3/13с1, Москва', inplace=True)
train['atm_address'].replace(to_replace=backslash_atm_address_count.index[9], value='улица Савушкина, 141, Санкт-Петербург', inplace=True)
train['atm_address'].replace(to_replace=backslash_atm_address_count.index[12], value='Новомытищинский проспект, 34, Москва', inplace=True)
train['atm_address'].replace(to_replace=backslash_atm_address_count.index[14], value='проспект Большевиков, 18, Санкт-Петербург', inplace=True)
train['atm_address'].replace(to_replace=backslash_atm_address_count.index[15], value='Марксистская улица, 1, Москва', inplace=True)
train['atm_address'].replace(to_replace=backslash_atm_address_count.index[16], value='Гражданский проспект, 41к2, Санкт-Петербург', inplace=True)
train['atm_address'].replace(to_replace=backslash_atm_address_count.index[18], value='улица Грекова, 8, Москва', inplace=True)
train['atm_address'].replace(to_replace=backslash_atm_address_count.index[23], value='Ракетный бульвар, 16, Москва', inplace=True)
train['atm_address'].replace(to_replace=backslash_atm_address_count.index[27], value='Новочеркасский проспект, 43/17, Санкт-Петербург', inplace=True)

# Остальные удалить
train.drop(train[train['atm_address'].str.contains("\\\\") == True].index, inplace=True)

# %%
# Для удобства анализа сделаю labelencoding на customer_id и terminal_id
label_encoder = LabelEncoder()
train['customer_id'] = label_encoder.fit_transform(train['customer_id'])
train['terminal_id'] = label_encoder.fit_transform(train['terminal_id'])

# %%
# Обнуление NaN адресов atm и pos
train[['atm_address', 'atm_address_lat', 'atm_address_lon',
       'pos_address', 'pos_address_lat', 'pos_address_lon']] = train[['atm_address', 'atm_address_lat', 'atm_address_lon', 
                                                                      'pos_address', 'pos_address_lat', 'pos_address_lon']].fillna(0)

# %%
# у 13 pos адресов координаты разные - исправляем
wrong_pos_address = []
with open('pos_address.txt', 'r') as file:
    for line in file:
        wrong_pos_address.append(line.strip())
        
geolocator = Yandex()

#0
location = geolocator.geocode('B. KAMENSCHIKI, 4MOSCOW')
#pos = train[train['pos_address'] == wrong_pos_address[0]]
#pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})

train['pos_address_lat'][train['pos_address'] == wrong_pos_address[0]] = location.latitude
train['pos_address_lon'][train['pos_address'] == wrong_pos_address[0]] = location.longitude

#1
train['pos_address_lat'][train['pos_address'] == wrong_pos_address[1]] = 59.2243102
train['pos_address_lon'][train['pos_address'] == wrong_pos_address[1]] = 39.8657153

#2 под вопросом, потому что обе точки имеют место быть
#train['pos_address_lat'][train['pos_address'] == wrong_pos_address[2]] = 55.7955715
#train['pos_address_lon'][train['pos_address'] == wrong_pos_address[2]] = 37.5937033

#3 
# тоже обе точки могут быть

#4
location = geolocator.geocode("5-1A, SUSCHEVSKIY VALMOSKVA")
train['pos_address_lat'][train['pos_address'] == wrong_pos_address[4]] = location.latitude
train['pos_address_lon'][train['pos_address'] == wrong_pos_address[4]] = location.longitude

#5
location = geolocator.geocode("'KOMMUNISTICHESKAYA STR 1MYTISCHY")
train['pos_address_lat'][train['pos_address'] == wrong_pos_address[5]] = location.latitude
train['pos_address_lon'][train['pos_address'] == wrong_pos_address[5]] = location.longitude

#6
location = geolocator.geocode("MIRA STR 51MYTISCHY")
train['pos_address_lat'][train['pos_address'] == wrong_pos_address[6]] = location.latitude
train['pos_address_lon'][train['pos_address'] == wrong_pos_address[6]] = location.longitude

#7
location = geolocator.geocode("42, SCHUKINSKAYA MOSKVA")
train['pos_address_lat'][train['pos_address'] == wrong_pos_address[7]] = location.latitude
train['pos_address_lon'][train['pos_address'] == wrong_pos_address[7]] = location.longitude

#8
#нормальная, отличие в 8 незначящем знаке

#9
location = geolocator.geocode("2, VETERANOV MYTISCHI")
train['pos_address_lat'][train['pos_address'] == wrong_pos_address[9]] = location.latitude
train['pos_address_lon'][train['pos_address'] == wrong_pos_address[9]] = location.longitude

#10
location = geolocator.geocode("55 BOLSHOY SAMPSONIEVSKIY PR SANKT-PETERBURG")
train['pos_address_lat'][train['pos_address'] == wrong_pos_address[10]] = location.latitude
train['pos_address_lon'][train['pos_address'] == wrong_pos_address[10]] = location.longitude

#11
location = geolocator.geocode("20 BOLSHOY SAMPSONIEVSKIY PRSANKT-PETERBURG")
train['pos_address_lat'][train['pos_address'] == wrong_pos_address[11]] = location.latitude
train['pos_address_lon'][train['pos_address'] == wrong_pos_address[11]] = location.longitude

#12
location = geolocator.geocode("Счастливая улица, 11, Усады")
train['pos_address_lat'][train['pos_address'] == wrong_pos_address[12]] = location.latitude
train['pos_address_lon'][train['pos_address'] == wrong_pos_address[12]] = location.longitude
# Out:
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Посмотрим, где нет ни atm ни pos

# %%
# Замена нулями координат atm и pos
train[['atm_address_lat', 'atm_address_lon', 'pos_address_lat', 'pos_address_lon']] = train[['atm_address_lat', 'atm_address_lon', 'pos_address_lat', 'pos_address_lon']].fillna(0)

# %%
no_atm_pos = train[(train['atm_address_lat'] == 0) & (train['pos_address_lat'] == 0)]
no_atm_pos.shape[0]
# Out:
# 97411

# %%
no_atm_pos[:10]
# Out:
#           amount atm_address  atm_address_lat  atm_address_lon       city  \
# 302067  3.836768         NaN              0.0              0.0  "Caf&#233
# 555784  2.366405         NaN              0.0              0.0    "OSN.PR
# 555788  2.243972         NaN              0.0              0.0    "OSN.PR
# 555795  2.487648         NaN              0.0              0.0    "OSN.PR
# 555797  2.260354         NaN              0.0              0.0    "OSN.PR
# 555805  2.287494         NaN              0.0              0.0    "OSN.PR
# 555808  2.225642         NaN              0.0              0.0    "OSN.PR
# 555816  2.364249         NaN              0.0              0.0    "OSN.PR
# 555821  2.496550         NaN              0.0              0.0    "OSN.PR
# 555824  2.330614         NaN              0.0              0.0    "OSN.PR
#
#              country  currency  customer_id  home_add_lat  home_add_lon   mcc  \
# 302067  -bar Campus"       NaN         4926        55.901        37.401  7000
# 555784           ZZ"       NaN         1810        55.639        37.611   235
# 555788           ZZ"       NaN         1810        55.639        37.611   169
# 555795           ZZ"       NaN         1810        55.639        37.611   304
# 555797           ZZ"       NaN         1810        55.639        37.611   183
# 555805           ZZ"       NaN         1810        55.639        37.611   200
# 555808           ZZ"       NaN         1810        55.639        37.611   168
# 555816           ZZ"       NaN         1810        55.639        37.611   227
# 555821           ZZ"       NaN         1810        55.639        37.611   324
# 555824           ZZ"       NaN         1810        55.639        37.611   217
#
#        pos_address  pos_address_lat  pos_address_lon  terminal_id  \
# 302067         NaN              0.0              0.0       172692
# 555784         NaN              0.0              0.0       172692
# 555788         NaN              0.0              0.0       172692
# 555795         NaN              0.0              0.0       172692
# 555797         NaN              0.0              0.0       172692
# 555805         NaN              0.0              0.0       172692
# 555808         NaN              0.0              0.0       172692
# 555816         NaN              0.0              0.0       172692
# 555821         NaN              0.0              0.0       172692
# 555824         NaN              0.0              0.0       172692
#
#        transaction_date  work_add_lat  work_add_lon
# 302067              NaN        55.533        37.618
# 555784              NaN           NaN           NaN
# 555788              NaN           NaN           NaN
# 555795              NaN           NaN           NaN
# 555797              NaN           NaN           NaN
# 555805              NaN           NaN           NaN
# 555808              NaN           NaN           NaN
# 555816              NaN           NaN           NaN
# 555821              NaN           NaN           NaN
# 555824              NaN           NaN           NaN

# %%
len(no_atm_pos['terminal_id'].unique())
# Out:
# 17648

# %%
no_atm_pos[no_atm_pos['terminal_id'] == 172692].shape[0]
# Out:
# 44

# %%
train[train['terminal_id'] == 172692].shape[0]
# Out:
# 44

# %%
# Число несовпадающих количеств terminal_id
count = 0
for i in tqdm(range(len(no_atm_pos['terminal_id'].unique()))):
    if (no_atm_pos[no_atm_pos['terminal_id'] == no_atm_pos['terminal_id'].unique()[i]].shape[0] != train[train['terminal_id'] == no_atm_pos['terminal_id'].unique()[i]].shape[0]):
        count += 1
print(count)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 17648/17648 [02:34<00:00, 114.01it/s]
# 25

# %%
terminal_id = []
for i in tqdm(range(len(no_atm_pos['terminal_id'].unique()))):
    if (no_atm_pos[no_atm_pos['terminal_id'] == no_atm_pos['terminal_id'].unique()[i]].shape[0] != train[train['terminal_id'] == no_atm_pos['terminal_id'].unique()[i]].shape[0]):
        terminal_id.append(i)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 17648/17648 [02:11<00:00, 134.03it/s]

# %%
print(terminal_id)
# Out:
# [275, 742, 770, 1606, 1650, 2183, 2802, 4026, 4140, 4316, 5180, 6147, 6386, 6560, 6946, 7122, 7274, 7351, 8083, 10484, 12307, 12354, 14490, 14877, 16627]

# %%
no_atm_pos['terminal_id'].unique()[275]
# Out:
# 6492

# %%
no_atm_pos[no_atm_pos['terminal_id'] == 6492].shape[0]
# Out:
# 12

# %%
train[train['terminal_id'] == 6492].shape[0]
# Out:
# 13

# %%
train[train['terminal_id'] == 6492]
# Out:
#           amount                                    atm_address  \
# 557595  2.360520                                            NaN
# 948285  4.466613  ROEV REVOLUCII 35 K 1\NVSIBR\630012    RUSRUS
# 948286  4.485451  ROEV REVOLUCII 35 K 1\NVSIBR\630012    RUSRUS
# 948287  4.467291  ROEV REVOLUCII 35 K 1\NVSIBR\630012    RUSRUS
# 948288  4.468131  ROEV REVOLUCII 35 K 1\NVSIBR\630012    RUSRUS
# 948289  3.564609  ROEV REVOLUCII 35 K 1\NVSIBR\630012    RUSRUS
# 948290  3.988495  ROEV REVOLUCII 35 K 1\NVSIBR\630012    RUSRUS
# 948291  3.659052  ROEV REVOLUCII 35 K 1\NVSIBR\630012    RUSRUS
# 948292  2.713506  ROEV REVOLUCII 35 K 1\NVSIBR\630012    RUSRUS
# 948293  4.355365  ROEV REVOLUCII 35 K 1\NVSIBR\630012    RUSRUS
# 948294  4.459974  ROEV REVOLUCII 35 K 1\NVSIBR\630012    RUSRUS
# 948295  3.781966  ROEV REVOLUCII 35 K 1\NVSIBR\630012    RUSRUS
# 948296  4.496618  ROEV REVOLUCII 35 K 1\NVSIBR\630012    RUSRUS
#
#         atm_address_lat  atm_address_lon           city country  currency  \
# 557595              0.0              0.0         MOSCOW     RUS     643.0
# 948285              0.0              0.0  NVSIBR            RUS     643.0
# 948286              0.0              0.0  NVSIBR            RUS     643.0
# 948287              0.0              0.0  NVSIBR            RUS     643.0
# 948288              0.0              0.0  NVSIBR            RUS     643.0
# 948289              0.0              0.0  NVSIBR            RUS     643.0
# 948290              0.0              0.0  NVSIBR            RUS     643.0
# 948291              0.0              0.0  NVSIBR            RUS     643.0
# 948292              0.0              0.0  NVSIBR            RUS     643.0
# 948293              0.0              0.0  NVSIBR            RUS     643.0
# 948294              0.0              0.0  NVSIBR            RUS     643.0
# 948295              0.0              0.0  NVSIBR            RUS     643.0
# 948296              0.0              0.0  NVSIBR            RUS     643.0
#
#         customer_id  home_add_lat  home_add_lon   mcc  \
# 557595         6383        54.933        83.123  4814
# 948285          894        54.960        83.179  6011
# 948286          894        54.960        83.179  6011
# 948287          894        54.960        83.179  6011
# 948288          894        54.960        83.179  6011
# 948289         1304        54.991        83.005  6011
# 948290          894        54.960        83.179  6011
# 948291         1304        54.991        83.005  6011
# 948292         8808        54.770        83.080  6011
# 948293         1304        54.991        83.005  6011
# 948294          894        54.960        83.179  6011
# 948295          894        54.960        83.179  6011
# 948296          894        54.960        83.179  6011
#
#                                          pos_address  pos_address_lat  \
# 557595  33 KOTELNICHESKAYA EMBMOSCOW157000    RUSRUS         55.74064
# 948285                                           NaN          0.00000
# 948286                                           NaN          0.00000
# 948287                                           NaN          0.00000
# 948288                                           NaN          0.00000
# 948289                                           NaN          0.00000
# 948290                                           NaN          0.00000
# 948291                                           NaN          0.00000
# 948292                                           NaN          0.00000
# 948293                                           NaN          0.00000
# 948294                                           NaN          0.00000
# 948295                                           NaN          0.00000
# 948296                                           NaN          0.00000
#
#         pos_address_lon  terminal_id transaction_date  work_add_lat  \
# 557595        37.647094         6492       2017-09-23        54.980
# 948285         0.000000         6492       2017-02-10        54.945
# 948286         0.000000         6492       2017-09-10        54.945
# 948287         0.000000         6492       2017-10-09        54.945
# 948288         0.000000         6492       2017-07-21        54.945
# 948289         0.000000         6492       2017-06-27           NaN
# 948290         0.000000         6492       2017-04-17        54.945
# 948291         0.000000         6492       2017-07-24           NaN
# 948292         0.000000         6492       2017-06-29        54.967
# 948293         0.000000         6492       2017-06-25           NaN
# 948294         0.000000         6492       2017-10-13        54.945
# 948295         0.000000         6492       2017-05-24        54.945
# 948296         0.000000         6492       2017-10-30        54.945
#
#         work_add_lon
# 557595        83.022
# 948285        82.850
# 948286        82.850
# 948287        82.850
# 948288        82.850
# 948289           NaN
# 948290        82.850
# 948291           NaN
# 948292        82.934
# 948293           NaN
# 948294        82.850
# 948295        82.850
# 948296        82.850

# %%
print(no_atm_pos[no_atm_pos['terminal_id'] == no_atm_pos['terminal_id'].unique()[terminal_id[1]]].shape[0])
print(train[train['terminal_id'] == no_atm_pos['terminal_id'].unique()[terminal_id[1]]].shape[0])
# Out:
# 9
# 11

# %%
train[train['terminal_id'] == no_atm_pos['terminal_id'].unique()[terminal_id[1]]]
# Out:
#           amount                           atm_address  atm_address_lat  \
# 82305   2.641953                                   NaN              0.0
# 312623  2.322353                                   NaN              0.0
# 956537  2.998182  ONALNAYA, 26\NIZVRT\628600    RUSRUS              0.0
# 956538  3.289432  ONALNAYA, 26\NIZVRT\628600    RUSRUS              0.0
# 956539  3.789248  ONALNAYA, 26\NIZVRT\628600    RUSRUS              0.0
# 956540  3.769091  ONALNAYA, 26\NIZVRT\628600    RUSRUS              0.0
# 956541  3.798301  ONALNAYA, 26\NIZVRT\628600    RUSRUS              0.0
# 956542  3.773197  ONALNAYA, 26\NIZVRT\628600    RUSRUS              0.0
# 956543  3.796158  ONALNAYA, 26\NIZVRT\628600    RUSRUS              0.0
# 956544  3.788632  ONALNAYA, 26\NIZVRT\628600    RUSRUS              0.0
# 956545  3.117398  ONALNAYA, 26\NIZVRT\628600    RUSRUS              0.0
#
#         atm_address_lon           city country  currency  customer_id  \
# 82305               0.0         STPETE     RUS     643.0         1905
# 312623              0.0         STPETE     RUS     643.0         8909
# 956537              0.0  NIZVRT            RUS     643.0         4275
# 956538              0.0  NIZVRT            RUS     643.0         4275
# 956539              0.0  NIZVRT            RUS     643.0         4275
# 956540              0.0  NIZVRT            RUS     643.0         4275
# 956541              0.0  NIZVRT            RUS     643.0         4275
# 956542              0.0  NIZVRT            RUS     643.0         4275
# 956543              0.0  NIZVRT            RUS     643.0         4275
# 956544              0.0  NIZVRT            RUS     643.0         4275
# 956545              0.0  NIZVRT            RUS     643.0         4275
#
#         home_add_lat  home_add_lon   mcc  \
# 82305         59.878        30.458  5732
# 312623        59.983        30.516  5732
# 956537        60.934        76.613  6011
# 956538        60.934        76.613  6011
# 956539        60.934        76.613  6011
# 956540        60.934        76.613  6011
# 956541        60.934        76.613  6011
# 956542        60.934        76.613  6011
# 956543        60.934        76.613  6011
# 956544        60.934        76.613  6011
# 956545        60.934        76.613  6011
#
#                                  pos_address  pos_address_lat  \
# 82305   3 NARODNAYA STSTPETE190000    RUSRUS        50.515609
# 312623  3 NARODNAYA STSTPETE190000    RUSRUS        50.515609
# 956537                                   NaN         0.000000
# 956538                                   NaN         0.000000
# 956539                                   NaN         0.000000
# 956540                                   NaN         0.000000
# 956541                                   NaN         0.000000
# 956542                                   NaN         0.000000
# 956543                                   NaN         0.000000
# 956544                                   NaN         0.000000
# 956545                                   NaN         0.000000
#
#         pos_address_lon  terminal_id transaction_date  work_add_lat  \
# 82305         36.609686        17469       2017-05-26           NaN
# 312623        36.609686        17469       2017-04-20        59.912
# 956537         0.000000        17469       2017-03-29           NaN
# 956538         0.000000        17469       2017-10-18           NaN
# 956539         0.000000        17469       2017-08-29           NaN
# 956540         0.000000        17469       2017-08-29           NaN
# 956541         0.000000        17469       2017-08-29           NaN
# 956542         0.000000        17469       2017-08-29           NaN
# 956543         0.000000        17469       2017-08-29           NaN
# 956544         0.000000        17469       2017-08-29           NaN
# 956545         0.000000        17469       2017-08-29           NaN
#
#         work_add_lon
# 82305            NaN
# 312623         30.29
# 956537           NaN
# 956538           NaN
# 956539           NaN
# 956540           NaN
# 956541           NaN
# 956542           NaN
# 956543           NaN
# 956544           NaN
# 956545           NaN

# %% [markdown]
# ### Когда вообще ни адресов ни координат atm, pos

# %%
# Замена адресов atm и pos
train[['atm_address', 'pos_address']] = train[['atm_address', 'pos_address']].fillna(0)

# %%
no_atm_pos = train[(train['atm_address_lat'] == 0) & (train['atm_address'] == 0) & (train['pos_address_lat'] == 0) & (train['pos_address'] == 0)]
no_atm_pos.shape[0]
# Out:
# 10165

# %%
len(no_atm_pos['terminal_id'].unique())
# Out:
# 2331

# %%
terminal_id_train_yes = []
terminal_id_train_no = []
for i in tqdm(range(len(no_atm_pos['terminal_id'].unique()))):
    if (no_atm_pos[no_atm_pos['terminal_id'] == no_atm_pos['terminal_id'].unique()[i]].shape[0] != train[train['terminal_id'] == no_atm_pos['terminal_id'].unique()[i]].shape[0]):
        terminal_id_train_yes.append(i)
    else:
        terminal_id_train_no.append(i)
print(len(terminal_id))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 
# 943585              0.0              0.0          897       2017-06-11
#
#         work_add_lat  work_add_lon
# 943536        60.040        30.004
# 943537           NaN           NaN
# 943538           NaN           NaN
# 943539           NaN           NaN
# 943540        60.035        30.002
# 943541        60.092        29.971
# 943542           NaN           NaN
# 943543           NaN           NaN
# 943544           NaN           NaN
# 943545           NaN           NaN
# 943546           NaN           NaN
# 943547           NaN           NaN
# 943548           NaN           NaN
# 943549           NaN           NaN
# 943550           NaN           NaN
# 943551           NaN           NaN
# 943552           NaN           NaN
# 943553           NaN           NaN
# 943554           NaN           NaN
# 943555           NaN           NaN
# 943556        60.040        30.004
# 943557           NaN           NaN
# 943558        59.922        30.300
# 943559           NaN           NaN
# 943560           NaN           NaN
# 943561        60.034        30.000
# 943562        60.034        30.000
# 943563           NaN           NaN
# 943564           NaN           NaN
# 943565           NaN           NaN
# 943566           NaN           NaN
# 943567           NaN           NaN
# 943568        60.040        30.004
# 943569           NaN           NaN
# 943570           NaN           NaN
# 943571        60.040        30.004
# 943572           NaN           NaN
# 943573           NaN           NaN
# 943574           NaN           NaN
# 943575        60.092        29.971
# 943576        59.936        30.353
# 943577        60.092        29.971
# 943578        60.092        29.971
# 943579           NaN           NaN
# 943580        59.937        30.271
# 943581           NaN           NaN
# 943582        60.040        30.004
# 943583           NaN           NaN
# 943584        60.004        30.114
# 943585        59.918        30.301

# %%
t1 = train[train['terminal_id'] == no_atm_pos['terminal_id'].unique()[terminal_id_train_yes[0]]]
t1['atm_address'].values
# Out:
# array(['OE HIGHWAY\\MOSKVA\\630004    RUSRUS',
#        'OE HIGHWAY\\MOSKVA\\630004    RUSRUS', 0], dtype=object)

# %% [markdown]
# адреса хер пойми какие, поэтому адреса надо чистить

# %% [markdown]
# ### Чистка адресов

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1224705 entries, 0 to 1224733
# Data columns (total 18 columns):
# amount              1224705 non-null float64
# atm_address         1224705 non-null object
# atm_address_lat     1224705 non-null float64
# atm_address_lon     1224705 non-null float64
# city                1224696 non-null object
# country             1224705 non-null object
# currency            1224661 non-null float64
# customer_id         1224705 non-null int64
# home_add_lat        1224689 non-null float64
# home_add_lon        1224689 non-null float64
# mcc                 1224705 non-null int64
# pos_address         1224705 non-null object
# pos_address_lat     1224705 non-null float64
# pos_address_lon     1224705 non-null float64
# terminal_id         1224705 non-null int64
# transaction_date    1224661 non-null object
# work_add_lat        664659 non-null float64
# work_add_lon        664659 non-null float64
# dtypes: float64(10), int64(3), object(5)
# memory usage: 177.5+ MB

# %%
atm_address = train['atm_address'].unique()
len(atm_address)
# Out:
# 17686

# %%
atm_address[:10]
# Out:
# array([0, 'R\\MINERALNYE VO\\357202    RUSRUS',
#        'YA STR  3\\MOSCOW\\109341    RUSRUS',
#        'Москва, ул. Таганская, д. 17-23', 'OKSARY\\             RUS',
#        '8-LUBYANKA\\MOSCOW\\123456    RUSRUS',
#        'Екатеринбург, ул. Металлургов, д. 87',
#        'YA ST.\\KHIMKI\\141400    RUSRUS', 'EREPOVETS\\162608    RUSRUS',
#        'IAN KUTA VILL\\RENON\\UNKNOWN   IDNIDN'], dtype=object)

# %%
train.to_csv

# %%
pd.DataFrame(atm_address).to_csv('atm_address.csv')

# %%
atm_address_count = train['atm_address'].value_counts()

# %%
atm_address_count.to_csv('atm_address_count.csv')

# %%
train[train['atm_address'] == '']

# %%
train['atm_address'][train['atm_address'].str.contains('Москва') == True][:5]
# Out:
# 942660    Москва, ул. Таганская, д. 17-23
# 942661    Москва, ул. Таганская, д. 17-23
# 942662    Москва, ул. Таганская, д. 17-23
# 942663    Москва, ул. Таганская, д. 17-23
# 942664    Москва, ул. Таганская, д. 17-23
# Name: atm_address, dtype: object

# %%
city = train['city'][:20]
city
# Out:
# 0     ST PETERSBURG
# 1     ST PETERSBURG
# 2     St Petersburg
# 3     ST PETERSBURG
# 4     ST PETERSBURG
# 5     ST PETERSBURG
# 6     ST PETERSBURG
# 7     ST PETERSBURG
# 8     ST PETERSBURG
# 9     ST PETERSBURG
# 10    SANKT-PETERBU
# 11      NOVOSIBIRSK
# 12      NOVOSIBIRSK
# 13      NOVOSIBIRSK
# 14      NOVOSIBIRSK
# 15      NOVOSIBIRSK
# 16      NOVOSIBIRSK
# 17      NOVOSIBIRSK
# 18      NOVOSIBIRSK
# 19      NOVOSIBIRSK
# Name: city, dtype: object

# %%
st = city.str.contains('ST')
st
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: city, dtype: bool

# %%
st[st == True].index
# Out:
# Int64Index([0, 1, 3, 4, 5, 6, 7, 8, 9], dtype='int64')

# %%
city[city.str.contains('ST') == True]
# Out:
# 0    ST PETERSBURG
# 1    ST PETERSBURG
# 3    ST PETERSBURG
# 4    ST PETERSBURG
# 5    ST PETERSBURG
# 6    ST PETERSBURG
# 7    ST PETERSBURG
# 8    ST PETERSBURG
# 9    ST PETERSBURG
# Name: city, dtype: object

# %%
# непонятный адрес "RADNAYA\RUS,445" есть только у 5912 и 1498 клиентов
train['customer_id'][train['atm_address'].str.contains('RADNAYA') == True].unique()
# Out:
# array([5912, 1498], dtype=int64)

# %%
c5912_RADNAYA = train[(train['customer_id'] == 5912) & (train['atm_address'].str.contains('RADNAYA') == True)]
c5912_RADNAYA
# Out:
#            amount               atm_address  atm_address_lat  atm_address_lon  \
# 1038989  4.605478  RADNAYA\             RUS              NaN              NaN
# 1038990  4.595060  RADNAYA\             RUS              NaN              NaN
# 1038991  4.310938  RADNAYA\             RUS              NaN              NaN
# 1038992  4.302670  RADNAYA\             RUS              NaN              NaN
# 1038993  4.286561  RADNAYA\             RUS              NaN              NaN
# 1038994  4.597065  RADNAYA\             RUS              NaN              NaN
# 1165574  4.463042  RADNAYA\             RUS              NaN              NaN
# 1165575  4.489924  RADNAYA\             RUS              NaN              NaN
# 1165576  4.600828  RADNAYA\             RUS              NaN              NaN
# 1165577  4.607250  RADNAYA\             RUS              NaN              NaN
# 1165578  4.619975  RADNAYA\             RUS              NaN              NaN
# 1165579  4.584626  RADNAYA\             RUS              NaN              NaN
# 1165580  4.581527  RADNAYA\             RUS              NaN              NaN
# 1165581  4.593383  RADNAYA\             RUS              NaN              NaN
# 1165582  4.461459  RADNAYA\             RUS              NaN              NaN
# 1166006       117773       2017-05-17        44.369        41.527
# 1166007       117773       2017-07-07        44.369        41.527
# 1166008       117773       2017-09-19        44.369        41.527
# 1166009       117773       2017-06-24        44.369        41.527
# 1166010       117773       2017-06-21        44.369        41.527
# 1166011       117773       2017-10-17        44.369        41.527
# 1166012       117773       2017-06-15        44.369        41.527
#
# [445 rows x 18 columns]

# %% [markdown]
# посмотрим можно ли определить адрес по terminal_id

# %%
# уникальные терминалы у клиента 5912 с адресом RADNAYA
c5912_RADNAYA['terminal_id'].unique()
# Out:
# array([144922, 117773], dtype=int64)

# %%
# терминал 144922 только у этого клиента
print(train['customer_id'][train['terminal_id'] == 144922].value_counts())
train[train['terminal_id'] == 144922]
# Out:
# 5912    6
# Name: customer_id, dtype: int64
#            amount               atm_address  atm_address_lat  atm_address_lon  \
# 1038989  4.605478  RADNAYA\             RUS              NaN              NaN
# 1038990  4.595060  RADNAYA\             RUS              NaN              NaN
# 1038991  4.310938  RADNAYA\             RUS              NaN              NaN
# 1038992  4.302670  RADNAYA\             RUS              NaN              NaN
# 1038993  4.286561  RADNAYA\             RUS              NaN              NaN
# 1038994  4.597065  RADNAYA\             RUS              NaN              NaN
#
#                   city country  currency  customer_id  home_add_lat  \
# 1038989  OTRADNAYA         RUS     643.0         5912        44.369
# 1038990  OTRADNAYA         RUS     643.0         5912        44.369
# 1038991  OTRADNAYA         RUS     643.0         5912        44.369
# 1038992  OTRADNAYA         RUS     643.0         5912        44.369
# 1038993  OTRADNAYA         RUS     643.0         5912        44.369
# 1038994  OTRADNAYA         RUS     643.0         5912        44.369
#
#          home_add_lon   mcc pos_address  pos_address_lat  pos_address_lon  \
# 1038989        41.527  6011         NaN              NaN              NaN
# 1038990        41.527  6011         NaN              NaN              NaN
# 1038991        41.527  6011         NaN              NaN              NaN
# 1038992        41.527  6011         NaN              NaN              NaN
# 1038993        41.527  6011         NaN              NaN              NaN
# 1038994        41.527  6011         NaN              NaN              NaN
#
#          terminal_id transaction_date  work_add_lat  work_add_lon
# 1038989       144922       2017-10-09        44.369        41.527
# 1038990       144922       2017-10-09        44.369        41.527
# 1038991       144922       2017-06-19        44.369        41.527
# 1038992       144922       2017-06-19        44.369        41.527
# 1038993       144922       2017-06-19        44.369        41.527
# 1038994       144922       2017-10-09        44.369        41.527

# %%
# терминал 117773 тоже только у этого клиента
train['customer_id'][train['terminal_id'] == 117773].value_counts()
# Out:
# 5912    439
# Name: customer_id, dtype: int64

# %%
train1 = train

# %%
train1[train1['atm_address'] == atm_address_count.index[45]].index
# Out:
# Int64Index([1038989, 1038990, 1038991, 1038992, 1038993, 1038994, 1165574,
#             1165575, 1165576, 1165577,
#             ...
#             1166003, 1166004, 1166005, 1166006, 1166007, 1166008, 1166009,
#             1166010, 1166011, 1166012],
#            dtype='int64', length=445)

# %%
train1.drop(train1[train1['atm_address'] == atm_address_count.index[45]].index, axis=0, inplace=True)

# %%
atm_address_count.index[45]
# Out:
# 'RADNAYA\\             RUS'

# %%
print(atm_address_count.index[43:48])
# Out:
# Index(['Москва, ул. Сергия Радонежского, д. 4',
#        'Москва, ул. 1-я Тверская-Ямская, д. 15', 'RADNAYA\             RUS',
#        'Подольск, ул. Полевановская, д. 9, (Заезд с ул. Орджоникидзе д. 25)',
#        'Анапа, ул. Шевченко, д. 73Б'],
#       dtype='object')

# %%
atm_address_count1 = train1['atm_address'].value_counts()
atm_address_count1.index[43:48]
# Out:
# Index(['Москва, ул. Сергия Радонежского, д. 4',
#        'Москва, ул. 1-я Тверская-Ямская, д. 15',
#        'Подольск, ул. Полевановская, д. 9, (Заезд с ул. Орджоникидзе д. 25)',
#        'Анапа, ул. Шевченко, д. 73Б', 'Москва, ш. Симферопольское, д. 3'],
#       dtype='object')

# %%
atm_address_count.index[46]
# Out:
# 'Подольск, ул. Полевановская, д. 9, (Заезд с ул. Орджоникидзе д. 25)'

# %%
train['customer_id'][train['atm_address'] == atm_address_count.index[46]].unique()
# Out:
# array([1177, 8625, 7463,  116, 7998, 5088, 1035, 8376, 2234, 6301, 8499,
#        1632,  281, 5505, 2520, 5195, 2690, 6784, 4403, 7899, 4141, 9656,
#        2453, 5711, 8387, 3212, 9290, 3269, 6152, 3321, 3238, 8279, 4051], dtype=int64)

# %%
train1['atm_address'][train1['atm_address'] == atm_address_count.index[46]].value = 'Подольск, ул. Полевановская, д. 9'

# %%
train1['atm_address'].fillna(0, inplace=True)

# %%
train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1224260 entries, 0 to 1224733
# Data columns (total 18 columns):
# amount              1224260 non-null float64
# atm_address         1224260 non-null object
# atm_address_lat     184680 non-null float64
# atm_address_lon     184680 non-null float64
# city                1224251 non-null object
# country             1224260 non-null object
# currency            1224216 non-null float64
# customer_id         1224260 non-null int64
# home_add_lat        1224244 non-null float64
# home_add_lon        1224244 non-null float64
# mcc                 1224260 non-null int64
# pos_address         924991 non-null object
# pos_address_lat     942614 non-null float64
# pos_address_lon     942614 non-null float64
# terminal_id         1224260 non-null int64
# transaction_date    1224216 non-null object
# work_add_lat        664214 non-null float64
# work_add_lon        664214 non-null float64
# dtypes: float64(10), int64(3), object(5)
# memory usage: 217.5+ MB

# %%
train1[train1['atm_address'] == atm_address_count.index[46]]
# Out:
#            amount                                        atm_address  \
# 1173134  2.987312  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173135  4.006400  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173136  3.606935  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173137  3.014655  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173138  3.854688  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173139  3.463546  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173140  2.998107  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173141  4.492525  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173142  2.690201  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173143  2.694462  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173144  3.009411  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173145  2.719516  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173146  2.982029  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173147  2.681897  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173148  2.699541  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173149  3.289240  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173150  2.707533  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173151  2.998535  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173152  2.687507  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173153  3.992459  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173154  3.472911  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173155  3.822330  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173156  3.001852  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173157  4.164482  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173158  4.363121  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173159  1.997445  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173160  2.313941  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173161  1.991890  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173162  2.460714  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173163  2.007258  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# ...           ...                                                ...
# 1173540  2.689997  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173541  3.014874  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173542  3.404830  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173543  2.989586  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173544  4.115304  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173545  4.719812  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173546  2.865801  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173547  4.717958  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173548  3.946854  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173549  3.683506  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173550  3.890652  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173551  4.153879  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173552  2.997346  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1173553  4.270445  Подольск, ул. Полевановская, д. 9, (Заезд с ул...
# 1
# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1224705 entries, 0 to 1224733
# Data columns (total 18 columns):
# amount              1224705 non-null float64
# atm_address         1224705 non-null object
# atm_address_lat     184680 non-null float64
# atm_address_lon     184680 non-null float64
# city                1224696 non-null object
# country             1224705 non-null object
# currency            1224661 non-null float64
# customer_id         1224705 non-null int64
# home_add_lat        1224689 non-null float64
# home_add_lon        1224689 non-null float64
# mcc                 1224705 non-null int64
# pos_address         924991 non-null object
# pos_address_lat     942614 non-null float64
# pos_address_lon     942614 non-null float64
# terminal_id         1224705 non-null int64
# transaction_date    1224661 non-null object
# work_add_lat        664659 non-null float64
# work_add_lon        664659 non-null float64
# dtypes: float64(10), int64(3), object(5)
# memory usage: 217.5+ MB

# %%
string = 'dfgd\dgd'

# %%
'\\' in string
# Out:
# True

# %%
ser = pd.Series(data = ['asd', 'as\df', 'wew\\\ewr'])

# %%
ser
# Out:
# 0         asd
# 1       as\df
# 2    wew\\ewr
# dtype: object

# %%
ser.str.contains('\\\\')
# Out:
# 0    False
# 1     True
# 2     True
# dtype: bool

# %%
train[train['atm_address'].str.contains("\\\\") == True]
# Out:
#            amount                                      atm_address  \
# 942658   3.541696                 R\MINERALNYE VO\357202    RUSRUS
# 942659   3.304900                YA STR  3\MOSCOW\109341    RUSRUS
# 942731   2.678472                          OKSARY\             RUS
# 942732   3.321838               8-LUBYANKA\MOSCOW\123456    RUSRUS
# 942807   2.306179                   YA ST.\KHIMKI\141400    RUSRUS
# 942808   4.191508                   YA ST.\KHIMKI\141400    RUSRUS
# 942809   3.692520                   YA ST.\KHIMKI\141400    RUSRUS
# 942810   2.689679                       EREPOVETS\162608    RUSRUS
# 942811   3.337487             IAN KUTA VILL\RENON\UNKNOWN   IDNIDN
# 942812   3.742778                   RIDIEN,\RENON\UNKNOWN   IDNIDN
# 942813   3.635329            NYY 1-Y BYSTR\MOSCOW\125171    RUSRUS
# 942814   3.758152            NYY 1-Y BYSTR\MOSCOW\125171    RUSRUS
# 942815   3.695204            NYY 1-Y BYSTR\MOSCOW\125171    RUSRUS
# 942816   3.464285            NYY 1-Y BYSTR\MOSCOW\125171    RUSRUS
# 942817   3.972948                        U\PHUKET\UNKNOWN   THATHA
# 942818   3.390393                               v\01000     KIOUKR
# 942819   2.458706                 0\St Petersburg\191123    78 RUS
# 942820   2.012450                 0\St Petersburg\191123    78 RUS
# 942821   3.712343                  STR\N.NOVGOROD\603142    RUSRUS
# 942822   3.320498                  STR\N.NOVGOROD\603142    RUSRUS
# 942823   3.705807                  STR\N.NOVGOROD\603142    RUSRUS
# 942824   3.319720               OE HIGHWAY\MOSKVA\630004    RUSRUS
# 942825   3.691022               OE HIGHWAY\MOSKVA\630004    RUSRUS
# 942827   3.005065                     65\VORONEZH\394018    RUSRUS
# 942828   4.014142                     65\VORONEZH\394018    RUSRUS
# 942980   3.465288                    R  1\SARANSK\430027    RUSRUS
# 942981   3.156380                    R  1\SARANSK\430027    RUSRUS
# 942818               NaN              NaN          223       2017-10-08
# 942819               NaN              NaN          241       2017-06-03
# 942820               NaN              NaN          241       2017-01-30
# 942821               NaN              NaN          328       2017-05-20
# 942822               NaN              NaN          328       2017-04-26
# 942823               NaN              NaN          328       2017-05-20
# 942824               NaN              NaN          376       2017-02-24
# 942825               NaN              NaN          376       2017-05-01
# 942827               NaN              NaN          423       2017-05-21
# 942828               NaN              NaN          423       2017-09-26
# 942980               NaN              NaN          495       2017-06-10
# 942981               NaN              NaN          495       2017-04-25
# 942982               NaN              NaN          507       2017-06-17
# 942983               NaN              NaN          507       2017-09-05
# 942984               NaN              NaN          507       2017-07-04
# ...                  ...              ...          ...              ...
# 1224606              NaN              NaN       208109       2017-06-15
# 1224607              NaN              NaN       208109       2017-07-03
# 1224608              NaN              NaN       208140       2017-03-10
# 1224609              NaN              NaN       208140       2017-08-05
# 1224610              NaN              NaN       208140       2017-03-27
# 1224611              NaN              NaN       208140       2017-06-24
# 1224612              NaN              NaN       208140       2017-05-01
# 1224613              NaN              NaN       208140       2017-06-30
# 1224614              NaN              NaN       208140       2017-09-17
# 1224615              NaN              NaN       208140       2017-02-14
# 1224616              NaN              NaN       208140       2017-04-15
# 1224617              NaN              NaN       208140       2017-05-27
# 1224618              NaN              NaN       208164       2017-06-05
# 1224619              NaN              NaN       208164       2017-07-12
# 1224620              NaN              NaN       208179       2017-09-04
# 1224621              NaN              NaN       208208       2017-03-09
# 1224622              NaN              NaN       208208       2017-03-24
# 1224623              NaN              NaN       208208       2017-03-24
# 1224624              NaN              NaN       208208       2017-03-24
# 1224625              NaN              NaN       208208       2017-07-08
# 1224626              NaN              NaN       208208       2017-05-20
# 1224628              NaN              NaN       208241       2017-05-10
# 1224629              NaN              NaN       208242       2017-05-02
# 1224630              NaN              NaN       208249       2017-04-17
# 1224631              NaN              NaN       208287       2017-06-03
# 1224632              NaN              NaN       208287       2017-06-02
# 1224633              NaN              NaN       208287       2017-05-13
# 1224634              NaN              NaN       208296       2017-03-02
# 1224635              NaN              NaN       208300       2017-08-19
# 1224636              NaN              NaN       208300       2017-03-28
#
#          work_add_lat  work_add_lon
# 942658         55.713        37.722
# 942659         55.609        38.074
# 942731         56.129        47.259
# 942732            NaN           NaN
# 942807            NaN           NaN
# 942808         55.785        37.391
# 942809         55.796        37.577
# 942810            NaN           NaN
# 942811         55.795        37.528
# 942812            NaN           NaN
# 942813         55.743        37.537
# 942814         55.743        37.537
# 942815         55.743        37.537
# 942816         55.726        37.647
# 942817         55.757        37.661
# 942818         59.926        30.359
# 942819         59.989        30.249
# 942820         59.815        30.444
# 942821         56.279        43.977
# 942822         56.279        43.977
# 942823         56.279        43.977
# 942824            NaN           NaN
# 942825         55.733        37.643
# 942827         51.680        39.181
# 942828         56.312        44.001
# 942980         54.167        45.143
# 942981         54.167        45.143
# 942982         55.425        37.576
# 942983            NaN           NaN
# 942984            NaN           NaN
# ...               ...           ...
# 1224606           NaN           NaN
# 1224607           NaN           NaN
# 1224608           NaN           NaN
# 1224609           NaN           NaN
# 1224610        55.730        37.484
# 1224611        55.730        37.484
# 1224612        55.730        37.484
# 1224613        55.730        37.484
# 1224614        55.813        37.491
# 1224615        55.730        37.484
# 1224616           NaN           NaN
# 1224617           NaN           NaN
# 1224618           NaN           NaN
# 1224619           NaN           NaN
# 1224620        55.772        37.593
# 1224621           NaN           NaN
# 1224622           NaN           NaN
# 1224623           NaN           NaN
# 1224624           NaN           NaN
# 1224625        56.466        84.994
# 1224626        56.466        84.994
# 1224628        55.018        82.921
# 1224629           NaN           NaN
# 1224630           NaN           NaN
# 1224631           NaN           NaN
# 1224632           NaN           NaN
# 1224633           NaN           NaN
# 1224634        54.687        20.532
# 1224635        55.696        37.616
# 1224636           NaN           NaN
#
# [81459 rows x 18 columns]

# %%
train['atm_address'][train['atm_address'].str.contains("\\\\") == True].value_counts()[:5]
# Out:
# RADNAYA\             RUS                                   445
# , ul. Marosejka, d. 3/13\Moskva\107045    45 RUS           403
# >  Moskv\Moskva\00000     RUSRUS                           297
# , 13        >  Krons\Kronshtadt\00000     RUSRUS           272
# ITER B 13-YA V.O. LINIYA\SANKT-PETERBU\199034    RUSRUS    245
# Name: atm_address, dtype: int64

# %%
len(train['atm_address'][train['atm_address'].str.contains("\\\\") == True].unique())
# Out:
# 16009

# %%
backslash_atm_address_count = train['atm_address'][train['atm_address'].str.contains("\\\\") == True].value_counts()

# %%
backslash_atm_address_count.to_csv('backslash_atm_address_count.csv')

# %%
backslash_atm_address_count.index[12]
# Out:
# 'VOMYTISHENSKY PROSPEKT 34/2 OTDELENYE UNICREDIT\\MOSCOW\\0722         RUS'

# %%
train['atm_address'][train['atm_address'].str.contains("0000") == True].value_counts()[:5]
# Out:
# >  Moskv\Moskva\00000     RUSRUS                             297
# , 13        >  Krons\Kronshtadt\00000     RUSRUS             272
# >  Krasn\Krasnoyarsk\00000     RUSRUS                        219
# LOVSKIY PR,11.32  >  Sankt\Sankt-Peterbu\00000     RUSRUS    155
# A, 32,34      >  Podol\Podolsk\00000     RUSRUS              121
# Name: atm_address, dtype: int64

# %%
train['atm_address'][train['atm_address'].str.contains("RUSRUS") == True].value_counts()[:5]
# Out:
# >  Moskv\Moskva\00000     RUSRUS                             297
# , 13        >  Krons\Kronshtadt\00000     RUSRUS             272
# ITER B 13-YA V.O. LINIYA\SANKT-PETERBU\199034    RUSRUS      245
# >  Krasn\Krasnoyarsk\00000     RUSRUS                        219
# LOVSKIY PR,11.32  >  Sankt\Sankt-Peterbu\00000     RUSRUS    155
# Name: atm_address, dtype: int64

# %%
wrong_atm_address_galka = train['atm_address'][train['atm_address'].str.contains(">") == True].value_counts()

# %%
wrong_atm_address_galka.to_csv('wrong_atm_address_galka.csv')

# %%
wrong_atm_address_galka.index[1]
# Out:
# '>  Moskv\\Moskva\\00000     RUSRUS'

# %%
train['terminal_id'][(train['atm_address'] == wrong_atm_address_galka.index[0])].unique()
# Out:
# array([ 26952,  34649,  49344,  74366, 153404, 179763, 186385, 187732,
#         27409,  38207,  47594,  55945,  61264, 115069, 145240, 150054,
#        165192, 176380], dtype=int64)

# %%
train[(train['terminal_id'] == 176380) & (train['pos_address_lat'] != 0)]
# Out:
# Empty DataFrame
# Columns: [amount, atm_address, atm_address_lat, atm_address_lon, city, country, currency, customer_id, home_add_lat, home_add_lon, mcc, pos_address, pos_address_lat, pos_address_lon, terminal_id, transaction_date, work_add_lat, work_add_lon]
# Index: []

# %%
train[train['atm_address'] == ', ul. Marosejka, d. 3/13\Moskva\107045    45 RUS,403']
# Out:
# Empty DataFrame
# Columns: [amount, atm_address, atm_address_lat, atm_address_lon, city, country, currency, customer_id, home_add_lat, home_add_lon, mcc, pos_address, pos_address_lat, pos_address_lon, terminal_id, transaction_date, work_add_lat, work_add_lon]
# Index: []

# %%
train1 = train

# %%
train1.drop(train1[train1['atm_address'].str.contains("\\\\") == True].index, inplace=True)

# %%
train1['atm_address'][train1['atm_address'].str.contains("\\\\") == True]
# Out:
# Series([], Name: atm_address, dtype: object)

# %% [markdown]
# #### pos_address

# %%
train['atm_address_lat']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
#             ...
# 1224704    51.556
# 1224705    51.561
# 1224706    51.559
# 1224707    51.560
# 1224708    51.557
# 1224709    51.557
# 1224710    51.560
# 1224711    51.560
# 1224712    51.556
# 1224713    51.555
# 1224714       NaN
# 1224715       NaN
# 1224716       NaN
# 1224717       NaN
# 1224718       NaN
# 1224719       NaN
# 1224720       NaN
# 1224721       NaN
# 1224722       NaN
# 1224723       NaN
# 1224724       NaN
# 1224725       NaN
# 1224726       NaN
# 1224727       NaN
# 1224728       NaN
# 1224729       NaN
# 1224730       NaN
# 1224731       NaN
# 1224732       NaN
# 1224733       NaN
# Name: atm_address_lat, Length: 1144721, dtype: float64

# %%
train.iloc[1000000]
# Out:
# amount                                          3.06293
# atm_address         Санкт-Петербург, ул. Ефимова, д. 4А
# atm_address_lat                                  59.922
# atm_address_lon                                  30.322
# city                                      ST PETERSBURG
# country                                             RUS
# currency                                            643
# customer_id                                        5486
# home_add_lat                                     59.962
# home_add_lon                                     30.286
# mcc                                                6011
# pos_address                                         NaN
# pos_address_lat                                     NaN
# pos_address_lon                                     NaN
# terminal_id                                      109579
# transaction_date                             2017-11-15
# work_add_lat                                     59.999
# work_add_lon                                     30.288
# Name: 1022825, dtype: object

# %%
train['atm_address'][train['customer_id'] == 5486].unique()
# Out:
# array([nan, 'Санкт-Петербург, пр. Комендантский, д. 13, корп.1',
#        'Санкт-Петербург, ул. Ефимова, д. 4А',
#        'Санкт-Петербург, пр. Комендантский, д. 3',
#        'Санкт-Петербург, пр. Каменоостровский, д. 13'], dtype=object)

# %%
train[train['atm_address'] == 'Санкт-Петербург, пр. Комендантский, д. 13, корп.1']
# Out:
#            amount                                        atm_address  \
# 997303   3.186045  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997304   4.283389  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997305   4.864826  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997306   5.155668  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997307   3.758354  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997308   3.680902  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997309   4.187703  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997310   3.596002  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997311   5.196073  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997312   3.912952  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997313   3.016829  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997314   3.584026  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997315   5.162911  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997316   3.652052  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997317   3.656818  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997318   4.379257  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 997319   4.695855  Санкт-Петербург, пр. Комендантский, д. 13, корп.1
# 
 LEVASHOVSKIY PR-T BLDSANKT-PETERBU190000    RUSRUS',
#        '13 LEVASHOVSKIY PR-TSANKT-PETERBU197110    RUSRUS',
#        '3A, KOMENDANTSKIY PR.SANKT-PETERBU197227    RUSRUS',
#        'LEVASHOVSKIY PR., D. 21, ASANKT-PETERBU190000    RUSRUS',
#        '14-18 B.ZELENINA STRSANKT-PETERBU190000    RUSRUS',
#        '34 GAKKELEVSKAYA STRSANKT-PETERBU190000    RUSRUS',
#        '15 CHKALOVSKIY PR-T BLD 13,SANKT-PETERBU190000    RUSRUS',
#        '2A VOLODARSKOGO STRSESTRORETSK197706    RUSRUS',
#        '16,B.ZELENINAS.PETERBURG197101    RUSRUS',
#        '16 B.ZELENINA STRSANKT-PETERBU190000    RUSRUS',
#        '7 A GEROYA SOVETSKOGO SOYUZAN.NOVGOROD603000    RUSRUS',
#        '25 A MICHURINA STRLYSKOVO606210    RUSRUS',
#        '1 KAZANSKAYA STR BLD G POM.PLYSKOVO606210    RUSRUS',
#        '(197110), Sankt-Peterburg g, Bolshaya ZSpb197110    40 RUS',
#        '1 KAZANSKAYA STRLYSKOVO606210    RUSRUS',
#        '42 KAMENNOOSTROVSKIY PR-T BLSANKT-PETERBU197022    RUSRUS',
#        '13 BOLSHAYA ZELENINA STR BLDSANKT-PETERBU197110    RUSRUS',
#        '33A ISPYTATELEY PR-TSANKT-PETERBU190000    RUSRUS',
#        '85 NEVSKIY AVE.SANKT-PETERBU191036    RUSRUS',
#        'BOLSHAYA ZELENINA UL D 15SANKT-PETERBU197110    78 RUS',
#        '13 LIT.A BOLSHAYA ZELENINA SSANKT-PETERBU190000    RUSRUS',
#        '11, CHKALOVSKIY PRST.PETERSBURG197110    RUSRUS',
#        '7 CHKALOVSKIY PR-T BLD TTS CSANKT-PETERBU190000    RUSRUS', nan], dtype=object)

# %%
train[train['pos_address'] == '13 LEVASHOVSKIY PR-T BLDSANKT-PETERBU190000    RUSRUS']
# Out:
#           amount atm_address  atm_address_lat  atm_address_lon           city  \
# 25879   2.794183         NaN              NaN              NaN  SANKT-PETERBU
# 50970   3.298309         NaN              NaN              NaN  SANKT-PETERBU
# 88547   2.271136         NaN              NaN              NaN  SANKT-PETERBU
# 103348  2.592405         NaN              NaN              NaN  SANKT-PETERBU
# 150063  1.834357         NaN              NaN              NaN  SANKT-PETERBU
# 163546  2.037888         NaN              NaN              NaN  SANKT-PETERBU
# 163547  2.115034         NaN              NaN              NaN  SANKT-PETERBU
# 167126  3.257722         NaN              NaN              NaN  SANKT-PETERBU
# 284588  1.617268         NaN              NaN              NaN  SANKT-PETERBU
# 284594  1.998302         NaN              NaN              NaN  SANKT-PETERBU
# 284653  1.975878         NaN              NaN              NaN  SANKT-PETERBU
# 284660  2.195139         NaN              NaN              NaN  SANKT-PETERBU
# 284675  1.981032         NaN              NaN              NaN  SANKT-PETERBU
# 284720  1.975189         NaN              NaN              NaN  SANKT-PETERBU
# 284723  1.087821         NaN              NaN              NaN  SANKT-PETERBU
# 284727  1.944698         NaN              NaN              NaN  SANKT-PETERBU
# 284728  2.011316         NaN              NaN              NaN  SANKT-PETERBU
# 284746  1.973466         NaN              NaN              NaN  SANKT-PETERBU
# 284787  1.766518         NaN              NaN              NaN  SANKT-PETERBU
# 284807  2.005612         NaN              NaN              NaN  SANKT-PETERBU
# 295299  2.142229         NaN              NaN              NaN  SANKT-PETERBU
# 295310  1.561541         NaN              NaN              NaN  SANKT-PETERBU
# 295313  1.981299         NaN              NaN              NaN  SANKT-PETERBU
# 295315  2.176431         NaN              NaN              NaN  SANKT-PETERBU
# 295320  1.708757         NaN              NaN              NaN  SANKT-PETERBU
# 295321  2.187468         NaN              NaN              NaN  SANKT-PETERBU
# 295322  1.876127         NaN              NaN              NaN  SANKT-PETERBU
# 295323  1.961279         NaN              NaN              NaN  SANKT-PETERBU
# 295337  2.013879         NaN              NaN              NaN  SANKT-PETERBU
# 295344  2.214315         NaN              NaN              NaN  SANKT-PETERBU
# ...          ...         ...              ...              ...            ...
# 753726  2.314905         NaN              NaN              NaN  SANKT-PETERBU
# 753729  2.601472         NaN              NaN              NaN  SANKT-PETERBU
# 753730  3.192756         NaN              NaN              NaN  SANKT-PETERBU
# 753734  2.872775         NaN              NaN              NaN  SANKT-PETERBU
# 753737  1.531612         NaN              NaN              NaN  SANKT-PETERBU
# 753738  1.986669         NaN              NaN              NaN  SANKT-PETERBU
# 753750  3.262577         NaN              NaN              NaN  SANKT-PETERBU
# 753752  2.711945         NaN              NaN              NaN  SANKT-PETERBU
# 753754  2.308408         NaN              NaN              NaN  SANKT-PETERBU
# 753761  2.883726         NaN              NaN              NaN  SANKT-PETERBU
# 753770  2.679341         NaN              NaN              NaN  SANKT-PETERBU
# 753771  2.484015         NaN              NaN              NaN  SANKT-PETERBU
# 753775  2.371702         NaN              NaN              NaN  SANKT-PETERBU
# 753778  2.885146         NaN              NaN              NaN  SANKT-PETERBU
# 753784  2.066237         NaN              NaN              NaN  SANKT-PETERBU
# 753787  2.325079         NaN              NaN              NaN  SANKT-PETERBU
# 753788  3.126615         NaN              NaN              NaN  SANKT-PETERBU
# 753792  2.304812         NaN              NaN              NaN  SANKT-PETERBU
# 753793  2.305253         NaN              NaN              NaN  SANKT-PETERBU
# 753796  2.032255         NaN              NaN              NaN  SANKT-PETERBU
# 753798  2.618461         NaN              NaN              NaN  SANKT-PETERBU
# 753800  2.316836         NaN              NaN              NaN  SANKT-PETERBU
# 753803  2.414051         NaN              NaN              NaN  SANKT-PETERBU
# 753808  2.624418         NaN              NaN              NaN  SANKT-PETERBU
# 753810  2.018344         NaN              NaN              NaN  SANKT-PETERBU
# 753811  3.329167         NaN              NaN              NaN  SANKT-PETERBU
# 753813  2.457284         NaN              NaN              NaN  SANKT-PETERBU
# 753814  2.485241         NaN              NaN              NaN  SANKT-PETERBU
# 861101  2.750043         NaN              NaN              NaN  SANKT-PETERBU
# 861102  2.885961         NaN              NaN              NaN  SANKT-PETERBU
# 753775        30.287019       152744       2017-04-21        60.041
# 753778        30.287019        93759       2017-05-12        60.041
# 753784        30.287019       157748       2017-09-09        60.041
# 753787        30.287019        93759       2017-05-09        60.041
# 753788        30.287019        93759       2017-07-08        60.041
# 753792        30.287019        93759       2017-04-14        60.041
# 753793        30.287019        93759       2017-06-19        60.041
# 753796        30.287019       128427       2017-06-22        60.041
# 753798        30.287019       157748       2017-08-20        60.041
# 753800        30.287019       128427       2017-07-10        60.041
# 753803        30.287019       155795       2017-10-20        60.041
# 753808        30.287019       128427       2017-06-21        60.041
# 753810        30.287019        93759       2017-07-31        60.041
# 753811        30.287019       157748       2017-10-20        60.041
# 753813        30.287019       128427       2017-08-24        60.041
# 753814        30.287019        93759       2017-06-03        60.041
# 861101        30.287019        93759       2017-06-19        59.952
# 861102        30.287019        93759       2017-06-21        59.952
#
#         work_add_lon
# 25879         37.591
# 50970         30.323
# 88547         30.276
# 103348        30.300
# 150063           NaN
# 163546           NaN
# 163547           NaN
# 167126           NaN
# 284588           NaN
# 284594           NaN
# 284653           NaN
# 284660           NaN
# 284675           NaN
# 284720           NaN
# 284723           NaN
# 284727           NaN
# 284728           NaN
# 284746           NaN
# 284787           NaN
# 284807           NaN
# 295299        30.284
# 295310        30.284
# 295313        30.284
# 295315        30.284
# 295320        30.284
# 295321        30.284
# 295322        30.284
# 295323        30.284
# 295337        30.284
# 295344        30.284
# ...              ...
# 753726        30.000
# 753729        30.000
# 753730        30.000
# 753734        30.000
# 753737        30.000
# 753738        30.000
# 753750        30.000
# 753752        30.000
# 753754        30.000
# 753761        30.000
# 753770        30.000
# 753771        30.000
# 753775        30.000
# 753778        30.000
# 753784        30.000
# 753787        30.000
# 753788        30.000
# 753792        30.000
# 753793        30.000
# 753796        30.000
# 753798        30.000
# 753800        30.000
# 753803        30.000
# 753808        30.000
# 753810        30.000
# 753811        30.000
# 753813        30.000
# 753814        30.000
# 861101        30.268
# 861102        30.268
#
# [129 rows x 18 columns]

# %%
train[(train['atm_address_lat'] != 0) & (train['pos_address_lat'] != 0)]
# Out:
# Empty DataFrame
# Columns: [amount, atm_address, atm_address_lat, atm_address_lon, city, country, currency, customer_id, home_add_lat, home_add_lon, mcc, pos_address, pos_address_lat, pos_address_lon, terminal_id, transaction_date, work_add_lat, work_add_lon]
# Index: []

# %% [markdown]
# #### проверить, что координаты pos нормальные

# %%
pos_address = train['pos_address'].unique()
len(pos_address)
# Out:
# 88958

# %%
count = 0
position = []
k = 0
for address in tqdm(pos_address):
#for address in pos_address:
    if address == 0: continue
    k += 1
    pos1 = train[train['pos_address']==address]  
    lat0 = pos1['pos_address_lat'].values[0]
    lon0 = pos1['pos_address_lon'].values[0]
    for i in range(pos1.shape[0]):
        if (lat0 != pos1['pos_address_lat'].values[i]) | (lon0 != pos1['pos_address_lon'].values[i]):
            count += 1
            position.append(address)
            with open('pos_address.txt', 'w') as file:
                for item in position:
                    file.write("%s\n" % item)
            break
    if (k%1000 == 0): print(k,' ',count)
print('count = ',count)
#  88%|████████████████████████████████████████████████████████████████▉         | 78000/88958 [2:03:08<17:17, 10.56it/s]
# 78000   13
#  89%|█████████████████████████████████████████████████████████████████▋        | 79000/88958 [2:04:42<15:43, 10.56it/s]
# 79000   13
#  90%|██████████████████████████████████████████████████████████████████▌       | 79999/88958 [2:06:45<14:11, 10.52it/s]
# 80000   13
#  91%|███████████████████████████████████████████████████████████████████▍      | 81000/88958 [2:08:09<12:35, 10.53it/s]
# 81000   13
#  92%|████████████████████████████████████████████████████████████████████▏     | 82000/88958 [2:09:37<10:59, 10.54it/s]
# 82000   13
#  93%|█████████████████████████████████████████████████████████████████████     | 82999/88958 [2:11:04<09:24, 10.55it/s]
# 83000   13
#  94%|█████████████████████████████████████████████████████████████████████▊    | 83999/88958 [2:12:26<07:49, 10.57it/s]
# 84000   13
#  96%|██████████████████████████████████████████████████████████████████████▋   | 84999/88958 [2:13:46<06:13, 10.59it/s]
# 85000   13
#  97%|███████████████████████████████████████████████████████████████████████▌  | 85999/88958 [2:15:05<04:38, 10.61it/s]
# 86000   13
#  98%|████████████████████████████████████████████████████████████████████████▎ | 86999/88958 [2:16:24<03:04, 10.63it/s]
# 87000   13
#  99%|█████████████████████████████████████████████████████████████████████████▏| 87999/88958 [2:17:43<01:30, 10.65it/s]
# 88000   13
# 100%|██████████████████████████████████████████████████████████████████████████| 88958/88958 [2:19:00<00:00, 10.67it/s]
# count =  13

# %%
position
# Out:
# ['B. KAMENSCHIKI, 4MOSCOW123456    RUSRUS',
#  'BLAGOVESCHENSKAYAVOLOGDA160001    RUSRUS',
#  'SUSCHEVSKIJ VAL 15MOSKVA127018    RUSRUS',
#  ', KOMSOMOLSKAYA SQ.MOSCOW107140    RUSRUS"',
#  '5-1A, SUSCHEVSKIY VALMOSKVA127018    RUSRUS',
#  'KOMMUNISTICHESKAYA STR 1MYTISCHY141011    RUSRUS',
#  'MIRA STR 51MYTISCHY141008    RUSRUS',
#  '42, SCHUKINSKAYAMOSKVA123182    RUSRUS',
#  '3 KIEVSKAYA STRSANKT-PETERBU190000    RUSRUS',
#  '-2, VETERANOVMYTISCHI141021    RUSRUS',
#  '55 BOLSHOY SAMPSONIEVSKIY PRSANKT-PETERBU194044    RUSRUS',
#  '20 BOLSHOY SAMPSONIEVSKIY PRSANKT-PETERBU190000    RUSRUS',
#  '11 SCHASTLIVAYA STRUSADY422624    RUSRUS']

# %%
geolocator = Yandex()

# %%
location = geolocator.geocode('B. KAMENSCHIKI, 4MOSCOW')
print(location.latitude, location.longitude)
# Out:
# 55.738176 37.653173

# %%
# уникальные значения координат
pos = train[train['pos_address'] == 'B. KAMENSCHIKI, 4MOSCOW123456    RUSRUS']
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0        55.737567        37.553126      8
# 1        55.737567        37.653087     11

# %%
#'B. KAMENSCHIKI, 4MOSCOW123456    RUSRUS'
#location = geolocator.geocode("BLAGOVESCHENSKAYAVOLOGDA")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
train1['pos_address_lat'][train1['pos_address'] == 'B. KAMENSCHIKI, 4MOSCOW123456    RUSRUS'] = pos['pos_address_lat'][0]
# Out:
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train1['pos_address_lat'][train1['pos_address'] == 'B. KAMENSCHIKI, 4MOSCOW123456    RUSRUS']
# Out:
# 10358     55.737567
# 10408     55.737567
# 17195     55.737567
# 17206     55.737567
# 110529    55.737567
# 129038    55.737567
# 258367    55.737567
# 323851    55.737567
# 470530    55.737567
# 470667    55.737567
# 543508    55.737567
# 543522    55.737567
# 543594    55.737567
# 543610    55.737567
# 543644    55.737567
# 745777    55.737567
# 759081    55.737567
# 854729    55.737567
# 854756    55.737567
# Name: pos_address_lat, dtype: float64

# %%
train['pos_address_lat'][train['pos_address'] == 'B. KAMENSCHIKI, 4MOSCOW123456    RUSRUS']
# Out:
# 10358     55.737567
# 10408     55.737567
# 17195     55.737567
# 17206     55.737567
# 110529    55.737567
# 129038    55.737567
# 258367    55.737567
# 323851    55.737567
# 470530    55.737567
# 470667    55.737567
# 543508    55.737567
# 543522    55.737567
# 543594    55.737567
# 543610    55.737567
# 543644    55.737567
# 745777    55.737567
# 759081    55.737567
# 854729    55.737567
# 854756    55.737567
# Name: pos_address_lat, dtype: float64

# %%
train2 = train.copy()

# %%
train2['pos_address_lat'][train2['pos_address'] == 'B. KAMENSCHIKI, 4MOSCOW123456    RUSRUS'] = 999
# Out:
# D:\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train2['pos_address_lat'][train2['pos_address'] == 'B. KAMENSCHIKI, 4MOSCOW123456    RUSRUS']
# Out:
# 10358     999.0
# 10408     999.0
# 17195     999.0
# 17206     999.0
# 110529    999.0
# 129038    999.0
# 258367    999.0
# 323851    999.0
# 470530    999.0
# 470667    999.0
# 543508    999.0
# 543522    999.0
# 543594    999.0
# 543610    999.0
# 543644    999.0
# 745777    999.0
# 759081    999.0
# 854729    999.0
# 854756    999.0
# Name: pos_address_lat, dtype: float64

# %% [markdown]
# 'BLAGOVESCHENSKAYAVOLOGDA160001    RUSRUS'

# %%
# уникальные значения координат
pos = train[train['pos_address'] == position[1]]
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0         59.22431        39.865715     94
# 1         59.25589        39.848200    126

# %%
pos['pos_address_lat'][0], pos['pos_address_lon'][0]
# Out:
# (59.224310299999999, 39.865715399999999)

# %%
location = geolocator.geocode("BLAGOVESCHENSKAYAVOLOGDA")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
#folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# SUSCHEVSKIJ VAL 15MOSKVA127018    RUSRUS

# %%
# уникальные значения координат
pos = train[train['pos_address'] == position[2]]
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0        55.778224        37.584323     93
# 1        55.795572        37.593703     32

# %%
pos['pos_address_lat'][1], pos['pos_address_lon'][1]
# Out:
# (55.795571500000001, 37.593703300000001)

# %%
location = geolocator.geocode("SUSCHEVSKIJ VAL 15MOSKVA")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ', KOMSOMOLSKAYA SQ.MOSCOW107140    RUSRUS"'

# %%
# уникальные значения координат
pos = train[train['pos_address'] == position[3]]
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0        55.774048        37.654861      2
# 1        55.776802        37.657352      7

# %%
location = geolocator.geocode("KOMSOMOLSKAYA SQ.MOSCOW")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
#folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# '5-1A, SUSCHEVSKIY VALMOSKVA127018    RUSRUS'

# %%
# уникальные значения координат
pos = train[train['pos_address'] == position[4]]
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0        55.699624        37.623173      1
# 1        55.792592        37.590429      1

# %%
location = geolocator.geocode("5-1A, SUSCHEVSKIY VALMOSKVA")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
train[train['pos_address'] == position[4]]
# Out:
#           amount atm_address  atm_address_lat  atm_address_lon    city  \
# 71229   2.589563           0              0.0              0.0  MOSKVA
# 754041  2.668986           0              0.0              0.0  MOSKVA
#
#        country  currency  customer_id  home_add_lat  home_add_lon   mcc  \
# 71229      RUS     643.0          171        53.981        50.175  7622
# 754041     RUS     643.0         5382        55.877        37.651  5732
#
#                                         pos_address  pos_address_lat  \
# 71229   5-1A, SUSCHEVSKIY VALMOSKVA127018    RUSRUS        55.792592
# 754041  5-1A, SUSCHEVSKIY VALMOSKVA127018    RUSRUS        55.699624
#
#         pos_address_lon  terminal_id transaction_date  work_add_lat  \
# 71229         37.590429       112035       2017-07-18           NaN
# 754041        37.623173       161986       2017-06-04        55.726
#
#         work_add_lon
# 71229            NaN
# 754041        37.642

# %% [markdown]
# 'KOMMUNISTICHESKAYA STR 1MYTISCHY141011    RUSRUS'

# %%
# уникальные значения координат
pos = train[train['pos_address'] == position[5]]
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0        52.593779       103.865708      8
# 1        55.887630        37.737740      2

# %%
location = geolocator.geocode("'KOMMUNISTICHESKAYA STR 1MYTISCHY")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# MIRA STR 51MYTISCHY141008    RUSRUS

# %%
# уникальные значения координат
pos = train[train['pos_address'] == position[6]]
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0        43.063420        44.652670      3
# 1        55.920456        37.708613      1

# %%
location = geolocator.geocode("MIRA STR 51MYTISCHY")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# '42, SCHUKINSKAYAMOSKVA123182    RUSRUS'

# %%
# уникальные значения координат
pos = train[train['pos_address'] == position[7]]
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0        55.669151        37.436850     10
# 1        55.809300        37.465638      1

# %%
location = geolocator.geocode("42, SCHUKINSKAYA MOSKVA")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 8

# %%
pos['pos_address_lat'][0], pos['pos_address_lat'][1]
# Out:
# (59.901675750000003, 59.901675750000003)

# %%
pos['pos_address_lon'][0], pos['pos_address_lon'][1]
# Out:
# (30.320608365300004, 30.320608365399998)

# %%
pos = train[train['pos_address'] == position[8]]
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0        59.901676        30.320608      1
# 1        59.901676        30.320608     10

# %%
location = geolocator.geocode("Санкт-Петербург киевская 3")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 9

# %%
pos = train[train['pos_address'] == position[9]]
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0        44.610649        40.139082     12
# 1        55.976357        37.607856     10

# %%
location = geolocator.geocode("2, VETERANOV MYTISCHI")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 10

# %%
pos = train[train['pos_address'] == position[10]]
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0        59.972041        30.340491     10
# 1        59.972215        30.340456      1

# %%
location = geolocator.geocode("55 BOLSHOY SAMPSONIEVSKIY PR SANKT-PETERBURG")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 11

# %%
pos = train[train['pos_address'] == position[11]]
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0        59.960381        30.344936      1
# 1        59.993598        30.332357      6

# %%
location = geolocator.geocode("20 BOLSHOY SAMPSONIEVSKIY PRSANKT-PETERBURG")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 12

# %%
pos = train[train['pos_address'] == position[12]]
pos = pos.groupby(['pos_address_lat', 'pos_address_lon']).size().reset_index().rename(columns={0:'count'})
pos
# Out:
#    pos_address_lat  pos_address_lon  count
# 0        55.673302        49.222460      4
# 1        55.683620        49.212692     22

# %%
location = geolocator.geocode("Счастливая улица, 11, Усады")

m = folium.Map(location=[location.latitude, location.longitude], zoom_start=10)
folium.Marker([location.latitude, location.longitude], popup='<i>True</i>', icon=folium.Icon(color='red', icon='font')).add_to(m)
for i in range(pos.shape[0]):
    pos_lat = pos['pos_address_lat'][i]
    pos_lon = pos['pos_address_lon'][i]

    folium.Marker([pos_lat, pos_lon], popup='pos' + str(i), icon=folium.Icon(color='blue', icon='usd')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
